# %% [markdown]
# # Behavioral figures

# %%
# Load data
import glob
import os.path as op
import numpy as np
import pandas as pd
import json
import os
from datetime import datetime

training_folder = '/home/hyruuk/GitHub/neuromod/shinobi_training'
scan_folder = '/home/hyruuk/GitHub/neuromod/shinobi'

# Obtain filelist
training_files = glob.glob(op.join(training_folder, 'sub*/ses*/*/*.bk2'))
scan_files = glob.glob(op.join(scan_folder, 'sub*/ses*/*/*.bk2'))

allfiles = sorted(training_files + scan_files)

def load_json(jsonfile):
    with open(jsonfile, 'r') as f:
        data = json.load(f)
    return data

def init_datadict():
    datadict = {
        'Subject':[], 
        'Level':[], 
        'Setup':[],
        'Health loss':[], 
        'Final score':[], 
        'Proportion cleared':[],
        'Days of training':[],
        'Index':[],
        'Cleared/Failed ratio':[],
        'Timestamp':[]
    }
    return datadict

def add_to_dict(datadict, replayfile, index=0):
    data = load_json(replayfile.replace('.bk2', '.json'))
    setup = 'Scan' if 'run-' in replayfile else 'Train'
    if data['FakeRep'] == False:
        datadict['Subject'].append(data['SubjectID'])
        datadict['Level'].append(data['Level'])
        datadict['Setup'].append(setup)
        datadict['Health loss'].append(-int(data['TotalHealthLost']))
        datadict['Final score'].append(int(data['FinalScore']))
        datadict['Proportion cleared'].append(float(data['PercentComplete']) if float(data['PercentComplete']) < 100 else 100)
        datadict['Days of training'].append(float(data['DaysOfTraining']) if setup == 'Train' else np.nan)
        datadict['Index'].append(index)
        datadict['Cleared/Failed ratio'].append(int(data['Cleared']))
        datadict['Timestamp'].append(int(data['LevelStartTimestamp']) if setup == 'Train' else np.nan)
    else:
        print(f'Fake replay discarded : {replayfile}')
    return datadict, index+1


datadict = init_datadict()
for subject in ['sub-01', 'sub-02', 'sub-04', 'sub-06']:
    for level in ['level-1', 'level-4', 'level-5']:
        for setup in ['Train', 'Scan']:
            filtered_files = [x for x in allfiles if subject in x and level in x]
            if setup == 'Scan':
                filtered_files = [x for x in filtered_files if 'run-' in x]
            else:
                filtered_files = [x for x in filtered_files if 'run-' not in x]
            index = 0
            for replayfile in filtered_files:
                try:
                    datadict, index = add_to_dict(datadict, replayfile, index)
                except Exception as e:
                    print(e)
                    print('Error from file : ', replayfile)

# Create a dataframe
df = pd.DataFrame(datadict)

# Split the training
for subject in np.unique(df.Subject):
    for level in np.unique(df.Level):
        minidf = df[(df['Setup']=='Train') & (df['Subject']==subject) & (df['Level']==level)]
        maxindex = np.max(minidf.Index) # Deprec
        training_start = datetime.fromtimestamp(np.min(minidf.Timestamp)) # Now we use timestamps instead of index
        for row in minidf.iterrows():
            current_date = datetime.fromtimestamp(row[1].Timestamp)
            if (current_date - training_start).days < 14:
                df.loc[row[0], 'Setup'] = 'Train (0-2w)'
            elif 14 <= (current_date - training_start).days < 56:
                df.loc[row[0], 'Setup'] = 'Train (2-8w)'
            else:
                df.loc[row[0], 'Setup'] = 'Train (8w+)'
# Out:
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-001/beh/sub-01_ses-001_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-013_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-014_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-036_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-038_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-039_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-043_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-005/beh/sub-01_ses-005_task-shinobi_level-1_rep-044_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-010/beh/sub-01_ses-010_task-shinobi_level-1_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-023/beh/sub-01_ses-023_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-024/beh/sub-01_ses-024_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-025/beh/sub-01_ses-025_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-028/beh/sub-01_ses-028_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-035/beh/sub-01_ses-035_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-036/beh/sub-01_ses-036_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-038/beh/sub-01_ses-038_task-shinobi_level-1_rep-002_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-007/gamelogs/sub-01_ses-007_task-shinobi_run-03_level-1_rep-04.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-007/gamelogs/sub-01_ses-007_task-shinobi_run-03_level-1_rep-04.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-009/gamelogs/sub-01_ses-009_task-shinobi_run-02_level-1_rep-02.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-009/gamelogs/sub-01_ses-009_task-shinobi_run-02_level-1_rep-02.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-027/beh/sub-01_ses-027_task-shinobi_level-4_rep-013_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-028/beh/sub-01_ses-028_task-shinobi_level-4_rep-010_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-036/beh/sub-01_ses-036_task-shinobi_level-4_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-041/beh/sub-01_ses-041_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-054/beh/sub-01_ses-054_task-shinobi_level-4_rep-004_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-007/gamelogs/sub-01_ses-007_task-shinobi_run-05_level-4_rep-05.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-007/gamelogs/sub-01_ses-007_task-shinobi_run-05_level-4_rep-05.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-010/gamelogs/sub-01_ses-010_task-shinobi_run-03_level-4_rep-03.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-010/gamelogs/sub-01_ses-010_task-shinobi_run-03_level-4_rep-03.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-012/gamelogs/sub-01_ses-012_task-shinobi_run-03_level-4_rep-03.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-01/ses-012/gamelogs/sub-01_ses-012_task-shinobi_run-03_level-4_rep-03.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-025/beh/sub-01_ses-025_task-shinobi_level-5_rep-017_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-01/ses-027/beh/sub-01_ses-027_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-001/beh/sub-02_ses-001_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-002/beh/sub-02_ses-002_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-003/beh/sub-02_ses-003_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-004/beh/sub-02_ses-004_task-shinobi_level-1_rep-005_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-005/beh/sub-02_ses-005_task-shinobi_level-1_rep-002_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-005/beh/sub-02_ses-005_task-shinobi_level-1_rep-003_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-005/beh/sub-02_ses-005_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-006/beh/sub-02_ses-006_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-006/beh/sub-02_ses-006_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-008/beh/sub-02_ses-008_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-009/beh/sub-02_ses-009_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-010/beh/sub-02_ses-010_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-021/beh/sub-02_ses-021_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-022/beh/sub-02_ses-022_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-029/beh/sub-02_ses-029_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-045/beh/sub-02_ses-045_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-055/beh/sub-02_ses-055_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-059/beh/sub-02_ses-059_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-059/beh/sub-02_ses-059_task-shinobi_level-1_rep-010_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-061/beh/sub-02_ses-061_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-062/beh/sub-02_ses-062_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-062/beh/sub-02_ses-062_task-shinobi_level-1_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-063/beh/sub-02_ses-063_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-063/beh/sub-02_ses-063_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-064/beh/sub-02_ses-064_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-064/beh/sub-02_ses-064_task-shinobi_level-1_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-064/beh/sub-02_ses-064_task-shinobi_level-1_rep-012_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-066/beh/sub-02_ses-066_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-067/beh/sub-02_ses-067_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-067/beh/sub-02_ses-067_task-shinobi_level-1_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-068/beh/sub-02_ses-068_task-shinobi_level-1_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-070/beh/sub-02_ses-070_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-077/beh/sub-02_ses-077_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-078/beh/sub-02_ses-078_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-079/beh/sub-02_ses-079_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-081/beh/sub-02_ses-081_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-082/beh/sub-02_ses-082_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-083/beh/sub-02_ses-083_task-shinobi_level-1_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-089/beh/sub-02_ses-089_task-shinobi_level-1_rep-004_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-006/gamelogs/sub-02_ses-006_task-shinobi_run-02_level-1_rep-02.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-006/gamelogs/sub-02_ses-006_task-shinobi_run-02_level-1_rep-02.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-012/gamelogs/sub-02_ses-012_task-shinobi_run-04_level-1_rep-05.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-012/gamelogs/sub-02_ses-012_task-shinobi_run-04_level-1_rep-05.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-012/gamelogs/sub-02_ses-012_task-shinobi_run-05_level-1_rep-06.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-012/gamelogs/sub-02_ses-012_task-shinobi_run-05_level-1_rep-06.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-015/gamelogs/sub-02_ses-015_task-shinobi_run-03_level-1_rep-03.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-015/gamelogs/sub-02_ses-015_task-shinobi_run-03_level-1_rep-03.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-017/beh/sub-02_ses-017_task-shinobi_level-4_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-018/beh/sub-02_ses-018_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-018/beh/sub-02_ses-018_task-shinobi_level-4_rep-016_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-018/beh/sub-02_ses-018_task-shinobi_level-4_rep-021_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-018/beh/sub-02_ses-018_task-shinobi_level-4_rep-026_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-019/beh/sub-02_ses-019_task-shinobi_level-4_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-020/beh/sub-02_ses-020_task-shinobi_level-4_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-021/beh/sub-02_ses-021_task-shinobi_level-4_rep-011_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-021/beh/sub-02_ses-021_task-shinobi_level-4_rep-023_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-023/beh/sub-02_ses-023_task-shinobi_level-4_rep-015_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-025/beh/sub-02_ses-025_task-shinobi_level-4_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-025/beh/sub-02_ses-025_task-shinobi_level-4_rep-014_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-028/beh/sub-02_ses-028_task-shinobi_level-4_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-029/beh/sub-02_ses-029_task-shinobi_level-4_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-030/beh/sub-02_ses-030_task-shinobi_level-4_rep-015_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-031/beh/sub-02_ses-031_task-shinobi_level-4_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-032/beh/sub-02_ses-032_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-032/beh/sub-02_ses-032_task-shinobi_level-4_rep-010_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-033/beh/sub-02_ses-033_task-shinobi_level-4_rep-010_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-034/beh/sub-02_ses-034_task-shinobi_level-4_rep-011_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-035/beh/sub-02_ses-035_task-shinobi_level-4_rep-012_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-038/beh/sub-02_ses-038_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-040/beh/sub-02_ses-040_task-shinobi_level-4_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-041/beh/sub-02_ses-041_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-046/beh/sub-02_ses-046_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-050/beh/sub-02_ses-050_task-shinobi_level-4_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-084/beh/sub-02_ses-084_task-shinobi_level-4_rep-004_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-002/gamelogs/sub-02_ses-002_task-shinobi_run-04_level-4_rep-04.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-02/ses-002/gamelogs/sub-02_ses-002_task-shinobi_run-04_level-4_rep-04.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-021/beh/sub-02_ses-021_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-029/beh/sub-02_ses-029_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-029/beh/sub-02_ses-029_task-shinobi_level-5_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-029/beh/sub-02_ses-029_task-shinobi_level-5_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-035/beh/sub-02_ses-035_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-036/beh/sub-02_ses-036_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-037/beh/sub-02_ses-037_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-038/beh/sub-02_ses-038_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-038/beh/sub-02_ses-038_task-shinobi_level-5_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-039/beh/sub-02_ses-039_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-043/beh/sub-02_ses-043_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-045/beh/sub-02_ses-045_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-047/beh/sub-02_ses-047_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-048/beh/sub-02_ses-048_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-049/beh/sub-02_ses-049_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-052/beh/sub-02_ses-052_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-053/beh/sub-02_ses-053_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-054/beh/sub-02_ses-054_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-058/beh/sub-02_ses-058_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-060/beh/sub-02_ses-060_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-02/ses-082/beh/sub-02_ses-082_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-001/beh/sub-04_ses-001_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-003/beh/sub-04_ses-003_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-004/beh/sub-04_ses-004_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-005/beh/sub-04_ses-005_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-007/beh/sub-04_ses-007_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-011/beh/sub-04_ses-011_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-012/beh/sub-04_ses-012_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-013/beh/sub-04_ses-013_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-014/beh/sub-04_ses-014_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-015/beh/sub-04_ses-015_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-016/beh/sub-04_ses-016_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-017/beh/sub-04_ses-017_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-018/beh/sub-04_ses-018_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-019/beh/sub-04_ses-019_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-019/beh/sub-04_ses-019_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-020/beh/sub-04_ses-020_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-021/beh/sub-04_ses-021_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-1_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-1_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-1_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-023/beh/sub-04_ses-023_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-023/beh/sub-04_ses-023_task-shinobi_level-1_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-023/beh/sub-04_ses-023_task-shinobi_level-1_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-024/beh/sub-04_ses-024_task-shinobi_level-1_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-024/beh/sub-04_ses-024_task-shinobi_level-1_rep-009_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-025/beh/sub-04_ses-025_task-shinobi_level-1_rep-005_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-002/gamelogs/sub-04_ses-002_task-shinobi_run-03_level-1_rep-03.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-002/gamelogs/sub-04_ses-002_task-shinobi_run-03_level-1_rep-03.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-006/gamelogs/sub-04_ses-006_task-shinobi_run-02_level-1_rep-02.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-006/gamelogs/sub-04_ses-006_task-shinobi_run-02_level-1_rep-02.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-009/gamelogs/sub-04_ses-009_task-shinobi_run-02_level-1_rep-02.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-009/gamelogs/sub-04_ses-009_task-shinobi_run-02_level-1_rep-02.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-02_level-1_rep-01.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-02_level-1_rep-01.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-03_level-1_rep-02.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-03_level-1_rep-02.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-05_level-1_rep-05.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-05_level-1_rep-05.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-003/beh/sub-04_ses-003_task-shinobi_level-4_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-004/beh/sub-04_ses-004_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-005/beh/sub-04_ses-005_task-shinobi_level-4_rep-008_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-007/beh/sub-04_ses-007_task-shinobi_level-4_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-010/beh/sub-04_ses-010_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-012/beh/sub-04_ses-012_task-shinobi_level-4_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-013/beh/sub-04_ses-013_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-014/beh/sub-04_ses-014_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-015/beh/sub-04_ses-015_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-016/beh/sub-04_ses-016_task-shinobi_level-4_rep-007_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-017/beh/sub-04_ses-017_task-shinobi_level-4_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-017/beh/sub-04_ses-017_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-019/beh/sub-04_ses-019_task-shinobi_level-4_rep-005_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-04_level-4_rep-03.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-04/ses-010/gamelogs/sub-04_ses-010_task-shinobi_run-04_level-4_rep-03.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-010/beh/sub-04_ses-010_task-shinobi_level-5_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-012/beh/sub-04_ses-012_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-013/beh/sub-04_ses-013_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-014/beh/sub-04_ses-014_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-015/beh/sub-04_ses-015_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-015/beh/sub-04_ses-015_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-016/beh/sub-04_ses-016_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-016/beh/sub-04_ses-016_task-shinobi_level-5_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-017/beh/sub-04_ses-017_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-017/beh/sub-04_ses-017_task-shinobi_level-5_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-018/beh/sub-04_ses-018_task-shinobi_level-5_rep-007_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-019/beh/sub-04_ses-019_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-019/beh/sub-04_ses-019_task-shinobi_level-5_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-020/beh/sub-04_ses-020_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-021/beh/sub-04_ses-021_task-shinobi_level-5_rep-003_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-5_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-5_rep-007_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-022/beh/sub-04_ses-022_task-shinobi_level-5_rep-011_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-023/beh/sub-04_ses-023_task-shinobi_level-5_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-023/beh/sub-04_ses-023_task-shinobi_level-5_rep-007_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-024/beh/sub-04_ses-024_task-shinobi_level-5_rep-006_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-024/beh/sub-04_ses-024_task-shinobi_level-5_rep-010_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-025/beh/sub-04_ses-025_task-shinobi_level-5_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-04/ses-025/beh/sub-04_ses-025_task-shinobi_level-5_rep-007_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-001/beh/sub-06_ses-001_task-shinobi_level-1_rep-002_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-002/beh/sub-06_ses-002_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-004/beh/sub-06_ses-004_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-005/beh/sub-06_ses-005_task-shinobi_level-1_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-005/beh/sub-06_ses-005_task-shinobi_level-1_rep-016_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-006/beh/sub-06_ses-006_task-shinobi_level-1_rep-020_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-009/beh/sub-06_ses-009_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-010/beh/sub-06_ses-010_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-013/beh/sub-06_ses-013_task-shinobi_level-1_rep-002_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-014/beh/sub-06_ses-014_task-shinobi_level-1_rep-002_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-015/beh/sub-06_ses-015_task-shinobi_level-1_rep-001_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-016/beh/sub-06_ses-016_task-shinobi_level-1_rep-001_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-006/beh/sub-06_ses-006_task-shinobi_level-4_rep-004_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-007/beh/sub-06_ses-007_task-shinobi_level-4_rep-018_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-010/beh/sub-06_ses-010_task-shinobi_level-4_rep-010_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-013/beh/sub-06_ses-013_task-shinobi_level-4_rep-001_gamedata.bk2
# 'FakeRep'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-014/beh/sub-06_ses-014_task-shinobi_level-4_rep-005_gamedata.bk2
# Fake replay discarded : /home/hyruuk/GitHub/neuromod/shinobi_training/sub-06/ses-013/beh/sub-06_ses-013_task-shinobi_level-5_rep-005_gamedata.bk2
# [Errno 2] No such file or directory: '/home/hyruuk/GitHub/neuromod/shinobi/sub-06/ses-013/gamelogs/sub-06_ses-013_task-shinobi_run-04_level-5_rep-01.json'
# Error from file :  /home/hyruuk/GitHub/neuromod/shinobi/sub-06/ses-013/gamelogs/sub-06_ses-013_task-shinobi_run-04_level-5_rep-01.bk2

# %% [markdown]
# ## Learning curves

# %%
os.makedirs('../data/processed', exist_ok=True)
df.to_csv('../data/processed/D1_behavioral_df.csv', index=False)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_theme(style="whitegrid")


# Load the example exercise dataset
#df = sns.load_dataset("exercise")
fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(4,4)

for idx_var, var in enumerate(['Final score', 'Proportion cleared', 'Health loss', 'Cleared/Failed ratio']):
    for idx_sub, sub in enumerate(np.unique(df['Subject'])):
        ax = plt.subplot(gs[idx_var, idx_sub])
        vmin = [0,20,-10,-0.1]
        vmax = [80000,100,0,1.1]
        #sns.stripplot(x="Setup", y=var, hue="Level",
        #              size=3, alpha=0.2,
        #              data=df[df['Subject']==sub], ax=ax)
        
        sns.pointplot(x="Setup", y=var, hue="Level",
                      capsize=.2, height=6, aspect=.75, 
                      errwidth=0.8, order=['Train (0-2w)', 'Train (2-8w)', 'Train (8w+)', 'Scan'],
                      data=df[df['Subject']==sub], ax=ax)
        
        # Polish
        ax.set_ylim([vmin[idx_var], vmax[idx_var]])
        plt.legend().remove()
        if idx_var == 0 and idx_sub == 3:
            handles, labels = ax.get_legend_handles_labels()
            ax.legend(handles=handles[:3], labels=labels[:3])
        if idx_var == 0:
            plt.title(sub)
        if not idx_var == 3:
            ax.set_xticklabels([])
            ax.set_xlabel('')
        if not idx_sub == 0:
            ax.set_yticklabels([])
            ax.set_ylabel('')
        plt.xticks(rotation=45)

# %% [markdown]
# ## Train vs Scan

# %%
# Select only the training data
lcurves_df = df[df['Setup'] != 'Scan']

# Apply a rolling median to smooth the curves
numerical_cols = ['Days of training', 'Final score', 'Proportion cleared', 'Health loss', 'Cleared/Failed ratio']
rolling_df = df[numerical_cols].rolling(window=5).mean()
lcurves_df[numerical_cols] = rolling_df

# %%
fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(4,4)

for idx_var, var in enumerate(['Final score', 'Proportion cleared', 'Health loss', 'Cleared/Failed ratio']):
    for idx_sub, sub in enumerate(np.unique(lcurves_df['Subject'])):
        ax = plt.subplot(gs[idx_var, idx_sub])
        vmin = np.min(lcurves_df[var])
        vmax = np.max(lcurves_df[var])+5
        if var == 'Cleared/Failed ratio':
            vmax += -5
        
        sns.lineplot(x="Days of training", y=var, hue="Level",
                      data=lcurves_df[lcurves_df['Subject']==sub], ax=ax)
        
        # Polish
        ax.set_ylim([vmin, vmax])
        
        plt.legend().remove()
        if idx_var == 0 and idx_sub == 3:
            handles, labels = ax.get_legend_handles_labels()
            ax.legend(handles=handles[:3], labels=labels[:3])

        if idx_var == 0:
            plt.title(sub)
        if not idx_var == 3:
            ax.set_xticklabels([])
            ax.set_xlabel('')
        if not idx_sub == 0:
            ax.set_yticklabels([])
            ax.set_ylabel('')

# %%
# Out:
#       Final score  Proportion cleared  Health loss  Cleared/Failed ratio
# 0             NaN                 NaN          NaN                   NaN
# 1             NaN                 NaN          NaN                   NaN
# 2             NaN                 NaN          NaN                   NaN
# 3             NaN                 NaN          NaN                   NaN
# 4          5410.0           47.589744        -16.0                   0.0
# ...           ...                 ...          ...                   ...
# 2000      15220.0          100.000000         -2.0                   1.0
# 2001      15230.0          100.000000         -2.0                   1.0
# 2002      15230.0          100.000000         -2.0                   1.0
# 2003      15230.0          100.000000         -4.0                   1.0
# 2004      15230.0          100.000000         -3.0                   1.0
#
# [1351 rows x 4 columns]
